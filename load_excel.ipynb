# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_excel('./data/2017.xls', encoding='utf-8')
df.head()
# Out:
#               학교  재학생수(A)    실수  수용가능인원(B)  기숙사수용률\n(C=B/Ax100)  1인실\n기숙사비  \
# 0  가톨릭대학교 _제2캠퍼스     1602    41        122                  7.6          0
# 1      건국대학교 _본교    17844  1728       3309                 18.5        585
# 2      경희대학교 _본교    28736  2509       5547                 19.3        316
# 3      고려대학교 _본교    26754  1281       2751                 10.3        484
# 4      광운대학교 _본교     8805    32        160                  1.8          0
#
#    2인실\n기숙사비  3인실\n기숙사비  4인실이상\n기숙사비  등록금\n(D=B)
# 0        229        146            0      8910.0
# 1        382          0            0      8192.3
# 2        298        225          101      7804.8
# 3        383        208            0      8256.9
# 4          0          0          103      7807.9

# %%
# dormi.columns[(index)]

# %%
a=dormi[1:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2051c9cd2a10> in <module>()
# ----> 1 a=dormi[1:2]
#
# NameError: name 'dormi' is not defined

# %%
print(list(a))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ab50db00fb1d> in <module>()
# ----> 1 print(list(a))
#
# NameError: name 'a' is not defined

# %%
dormi=pd.pivot_table( df, index=['학교'] )
dormi
# Out:
#                1인실\n기숙사비  2인실\n기숙사비  3인실\n기숙사비  4인실이상\n기숙사비  \
# 학교
# 가톨릭대학교 _제2캠퍼스          0        229        146            0
# 건국대학교 _본교            585        382          0            0
# 경희대학교 _본교            316        298        225          101
# 고려대학교 _본교            484        383        208            0
# 광운대학교 _본교              0          0          0          103
# 국민대학교 _본교              0        239        193          189
# 덕성여자대학교 _본교          290        220          0          235
# 동국대학교 _본교            478        338          0          148
# 동덕여자대학교 _본교            0        304          0          228
# 명지대학교 _제2캠퍼스           0        325          0          236
# 삼육대학교 _본교            254          0          0          121
# 상명대학교 _본교            257        167        216          100
# 서강대학교 _본교              0        387          0          180
# 서경대학교 _본교              0        186          0           88
# 서울과학기술대학교 _본교        395        206        202          165
# ...

# %%
dormi.index

# %%
for name in dormi.index:
    print(name)

# %%
print(dormi.loc[ '가톨릭대학교 _제2캠퍼스' ])
print(list(dormi.loc[ '가톨릭대학교 _제2캠퍼스' ]))
